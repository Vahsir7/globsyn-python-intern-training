# %%
import numpy as np
import pandas as pd

# %% [markdown]
# read_csv is used in pandas to access a csv file it takes raw string as input

# %%
pd.read_csv(r'iris.csv')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# info() - > is used to check the general contents of the file and also detecting any discrepensy in data

# %%
df = pd.read_csv(r'iris.csv')
df.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# .describe()->Generate descriptive statistics
#
# Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset's distribution, excluding NaN values.
# Analyzes both numeric and object series, as well as DataFrame column sets of mixed data types. The output will vary depending on what is provided.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.describe(include="all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
df.describe(include="object")
# Out:
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %% [markdown]
# Accessing rows and columns

# %%
df.head(5)#shows n number of rows from beginning
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail(5)#shows n number of rows from the end
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.sample(10)#picks 10 random rows
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 89            5.5          2.5           4.0          1.3  versicolor
# 40            5.0          3.5           1.3          0.3      setosa
# 86            6.7          3.1           4.7          1.5  versicolor
# 63            6.1          2.9           4.7          1.4  versicolor
# 82            5.8          2.7           3.9          1.2  versicolor
# 19            5.1          3.8           1.5          0.3      setosa
# 140           6.7          3.1           5.6          2.4   virginica
# 138           6.0          3.0           4.8          1.8   virginica
# 53            5.5          2.3           4.0          1.3  versicolor
# 87            6.3          2.3           4.4          1.3  versicolor

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns=['spl','spw','pl','pw','sp']#to change columns 
df
# Out:
#      spl  spw   pl   pw         sp
# 0    5.1  3.5  1.4  0.2     setosa
# 1    4.9  3.0  1.4  0.2     setosa
# 2    4.7  3.2  1.3  0.2     setosa
# 3    4.6  3.1  1.5  0.2     setosa
# 4    5.0  3.6  1.4  0.2     setosa
# ..   ...  ...  ...  ...        ...
# 145  6.7  3.0  5.2  2.3  virginica
# 146  6.3  2.5  5.0  1.9  virginica
# 147  6.5  3.0  5.2  2.0  virginica
# 148  6.2  3.4  5.4  2.3  virginica
# 149  5.9  3.0  5.1  1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# * TO ACCESS SPECIFIC COLUMNS

# %%
df[['sp']]#prints specific column type = series
# Out:
#             sp
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
sl = df[['spl','spw']]
sl
# Out:
#      spl  spw
# 0    5.1  3.5
# 1    4.9  3.0
# 2    4.7  3.2
# 3    4.6  3.1
# 4    5.0  3.6
# ..   ...  ...
# 145  6.7  3.0
# 146  6.3  2.5
# 147  6.5  3.0
# 148  6.2  3.4
# 149  5.9  3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# * TO ACCESS SPECIFIC ROWS OF A SPECIFIC COLUMNS

# %%
df[['spl','pl']].loc[[0,10,23]]#multiple specifies column with targeted rows
# Out:
#     spl   pl
# 0   5.1  1.4
# 10  5.4  1.5
# 23  5.1  1.7

# %%
print(df.loc[[0,50,60],['pl']])#specified column
print(df.loc[[10,45,100]])#all columns
# Out:
#      pl
# 0   1.4
# 50  4.7
# 60  3.5
#      spl  spw   pl   pw         sp
# 10   5.4  3.7  1.5  0.2     setosa
# 45   4.8  3.0  1.4  0.3     setosa
# 100  6.3  3.3  6.0  2.5  virginica

# %%
sr = df.iloc[10:52:2,[0,4]]# iloc -> index location use to select via index only
sr
# Out:
#     spl          sp
# 10  5.4      setosa
# 12  4.8      setosa
# 14  5.8      setosa
# 16  5.4      setosa
# 18  5.7      setosa
# 20  5.4      setosa
# 22  4.6      setosa
# 24  4.8      setosa
# 26  5.0      setosa
# 28  5.2      setosa
# 30  4.8      setosa
# 32  5.2      setosa
# 34  4.9      setosa
# 36  5.5      setosa
# 38  4.4      setosa
# 40  5.0      setosa
# 42  4.4      setosa
# 44  5.1      setosa
# 46  5.1      setosa
# 48  5.3      setosa
# 50  7.0  versicolor

# %%
sl_avg = df['spl'].mean() 
sl_avg
# Out:
# 5.843333333333334

# %%
so = df[df['spl']>sl_avg]
so[['spl','sp']]
# Out:
#      spl          sp
# 50   7.0  versicolor
# 51   6.4  versicolor
# 52   6.9  versicolor
# 54   6.5  versicolor
# 56   6.3  versicolor
# ..   ...         ...
# 145  6.7   virginica
# 146  6.3   virginica
# 147  6.5   virginica
# 148  6.2   virginica
# 149  5.9   virginica
#
# [70 rows x 2 columns]

# %%
si = df[df['spl']>df['spl'].mean()][['spl','sp']] #comprehend the previous 3 codes
si
# Out:
#      spl          sp
# 50   7.0  versicolor
# 51   6.4  versicolor
# 52   6.9  versicolor
# 54   6.5  versicolor
# 56   6.3  versicolor
# ..   ...         ...
# 145  6.7   virginica
# 146  6.3   virginica
# 147  6.5   virginica
# 148  6.2   virginica
# 149  5.9   virginica
#
# [70 rows x 2 columns]

# %%
si = df[df['spl']>df['spl'].mean()].iloc[0:10,[0,4]] #only display first 10 columns which satisfies the condition
si
# Out:
#     spl          sp
# 50  7.0  versicolor
# 51  6.4  versicolor
# 52  6.9  versicolor
# 54  6.5  versicolor
# 56  6.3  versicolor
# 58  6.6  versicolor
# 61  5.9  versicolor
# 62  6.0  versicolor
# 63  6.1  versicolor
# 65  6.7  versicolor

# %%
df1 = df.drop('sp',axis=1) #to drop any column
df1
# Out:
#      spl  spw   pl   pw
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
df1.corr() #correlation
# Out:
#           spl       spw        pl        pw
# spl  1.000000 -0.117570  0.871754  0.817941
# spw -0.117570  1.000000 -0.428440 -0.366126
# pl   0.871754 -0.428440  1.000000  0.962865
# pw   0.817941 -0.366126  0.962865  1.000000

# %%
df.sp.value_counts() #value count of species
# Out:
# sp
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.sp.nunique() #no of unique data present
# Out:
# 3

# %%
df.sort_values(by=['spl','pl']) #sorting rows wrt to columns
# Out:
#      spl  spw   pl   pw         sp
# 13   4.3  3.0  1.1  0.1     setosa
# 38   4.4  3.0  1.3  0.2     setosa
# 42   4.4  3.2  1.3  0.2     setosa
# 8    4.4  2.9  1.4  0.2     setosa
# 41   4.5  2.3  1.3  0.3     setosa
# ..   ...  ...  ...  ...        ...
# 135  7.7  3.0  6.1  2.3  virginica
# 117  7.7  3.8  6.7  2.2  virginica
# 122  7.7  2.8  6.7  2.0  virginica
# 118  7.7  2.6  6.9  2.3  virginica
# 131  7.9  3.8  6.4  2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.replace(['setosa'],['seto'])#replace target value, new value
# Out:
#      spl  spw   pl   pw         sp
# 0    5.1  3.5  1.4  0.2       seto
# 1    4.9  3.0  1.4  0.2       seto
# 2    4.7  3.2  1.3  0.2       seto
# 3    4.6  3.1  1.5  0.2       seto
# 4    5.0  3.6  1.4  0.2       seto
# ..   ...  ...  ...  ...        ...
# 145  6.7  3.0  5.2  2.3  virginica
# 146  6.3  2.5  5.0  1.9  virginica
# 147  6.5  3.0  5.2  2.0  virginica
# 148  6.2  3.4  5.4  2.3  virginica
# 149  5.9  3.0  5.1  1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.groupby('sp').mean() #grouped mean
# Out:
#               spl    spw     pl     pw
# sp
# setosa      5.006  3.428  1.462  0.246
# versicolor  5.936  2.770  4.260  1.326
# virginica   6.588  2.974  5.552  2.026

# %%
df.groupby('sp').agg(['mean','std']) #aggreated
# Out:
#               spl              spw               pl               pw
#              mean       std   mean       std   mean       std   mean       std
# sp
# setosa      5.006  0.352490  3.428  0.379064  1.462  0.173664  0.246  0.105386
# versicolor  5.936  0.516171  2.770  0.313798  4.260  0.469911  1.326  0.197753
# virginica   6.588  0.635880  2.974  0.322497  5.552  0.551895  2.026  0.274650

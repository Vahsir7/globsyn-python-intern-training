# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
n=np.array([1 for i in range(100)])
type(n)
# Out:
# numpy.ndarray

# %%
plt.figure()
plt.pie(n)
plt.show()

# %%
# Out:
# [0.1, 0.25, 0.4, 0.5499999999999999, 0.7, 0.85, 0.9999999999999999, 1.1500000000000001, 1.3, 1.45, 1.6, 1.75, 1.9, 2.05, 2.2, 2.35, 2.5, 2.65, 2.8, 2.95, 3.1, 3.25, 3.4, 3.55, 3.6999999999999997, 3.85, 4.0, 4.1499999999999995, 4.3, 4.449999999999999, 4.6, 4.749999999999999, 4.8999999999999995, 5.05, 5.199999999999999, 5.35, 5.499999999999999, 5.6499999999999995, 5.8, 5.949999999999999, 6.1, 6.249999999999999, 6.3999999999999995, 6.55, 6.699999999999999, 6.85, 6.999999999999999, 7.1499999999999995, 7.299999999999999, 7.449999999999999, 7.6, 7.749999999999999, 7.8999999999999995, 8.049999999999999, 8.2, 8.35, 8.5, 8.649999999999999, 8.799999999999999, 8.95, 9.1, 9.25, 9.399999999999999, 9.549999999999999, 9.7, 9.85, 10.0, 10.149999999999999, 10.299999999999999, 10.45, 10.6, 10.75, 10.899999999999999, 11.049999999999999, 11.2, 11.35, 11.5, 11.649999999999999, 11.799999999999999, 11.95, 12.1, 12.25, 12.399999999999999, 12.549999999999999, 12.7, 12.85, 13.0, 13.149999999999999, 13.2999999
# ...

# %%
explode = [float(count + i * 0.01) for i in range(len(n))]
print(explode)
#make a donut chart
count=0.1
plt.figure()
#plt.pie(n, wedgeprops=dict(width=0.3))
#exploding them
plt.pie(n, wedgeprops=dict(width=0.3), explode=explode)
plt.show()
# Out:
# [0.1, 0.11, 0.12000000000000001, 0.13, 0.14, 0.15000000000000002, 0.16, 0.17, 0.18, 0.19, 0.2, 0.21000000000000002, 0.22, 0.23, 0.24000000000000002, 0.25, 0.26, 0.27, 0.28, 0.29000000000000004, 0.30000000000000004, 0.31, 0.32, 0.33, 0.33999999999999997, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4, 0.41000000000000003, 0.42000000000000004, 0.43000000000000005, 0.44000000000000006, 0.45000000000000007, 0.45999999999999996, 0.47, 0.48, 0.49, 0.5, 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.5700000000000001, 0.58, 0.59, 0.6, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.6799999999999999, 0.69, 0.7, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8, 0.8099999999999999, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.0, 1.01, 1.02, 1.03, 1.04, 1.05, 1.06, 1.07, 1.08, 1.09]
